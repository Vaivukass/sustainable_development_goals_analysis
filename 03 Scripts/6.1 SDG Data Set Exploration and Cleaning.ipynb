# %% [markdown]
# ## Table of Contents
# * [1. Importing Libraries](#1.-Importing-Libraries)
# * [2. Importing Data](#2.-Importing-Data)
# * [3. Data Eploration](#3.-Data-Exploration)
# * [4. Data Cleaning](#4.-Data-Cleaning)
#     * [4.1 Renaming Columns](#4.1-Renaming-Columns)
#     * [4.2 Dropping / Adding Columns](#4.2-Dropping-/-Adding-Columns)
#     * [4.3 Changing Data Types](#4.3-Changing-Data-Types)
#     * [4.4 Finding And Addressing Duplicates](#4.4-Finding-And-Addressing-Duplicates)
#     * [4.5 Handling Missing Values](#4.5-Handling-Missing-Values)
# * [5. Exporting Data](#5.-Exporting-Data)

# %% [markdown]
# ## 1. Importing Libraries

# %%
import pandas as pd
import os
import numpy as np

# %% [markdown]
# ## 2. Importing Data

# %%
# Creating a reusable path to my data

path = r'C:\Users\vaiva\OneDrive\Documents\CareerFoundry\Achievement 6 SDG'

# %%
# Importing 'SDG 2000-2022' data

df = pd.read_csv(os.path.join(path,'02 Data', 'Original Data','sdg_index_2000-2022.csv'), index_col=False)

# %% [markdown]
# ## 3. Data Exploration

# %%
df.head()
# Out:
#   country_code      country  year  sdg_index_score  goal_1_score  \
# 0          AFG  Afghanistan  2000             36.0          28.8
# 1          AFG  Afghanistan  2001             36.3          28.8
# 2          AFG  Afghanistan  2002             36.3          28.8
# 3          AFG  Afghanistan  2003             36.7          28.8
# 4          AFG  Afghanistan  2004             37.1          28.8
#
#    goal_2_score  goal_3_score  goal_4_score  goal_5_score  goal_6_score  ...  \
# 0          27.3          19.2           1.6          20.8          32.4  ...
# 1          30.6          19.4           1.6          20.8          32.4  ...
# 2          30.7          19.7           1.6          20.8          32.7  ...
# 3          32.5          19.9           1.6          20.8          33.0  ...
# 4          32.1          21.1           1.6          20.8          33.3  ...
#
#    goal_8_score  goal_9_score  goal_10_score  goal_11_score  goal_12_score  \
# ...

# %%
df.shape
# Out:
# (4140, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4140 entries, 0 to 4139
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country_code     4140 non-null   object
#  1   country          4140 non-null   object
#  2   year             4140 non-null   int64
#  3   sdg_index_score  4140 non-null   float64
#  4   goal_1_score     4140 non-null   float64
#  5   goal_2_score     4140 non-null   float64
#  6   goal_3_score     4140 non-null   float64
#  7   goal_4_score     4140 non-null   float64
#  8   goal_5_score     4140 non-null   float64
#  9   goal_6_score     4140 non-null   float64
#  10  goal_7_score     4140 non-null   float64
#  11  goal_8_score     4140 non-null   float64
#  12  goal_9_score     4140 non-null   float64
#  13  goal_10_score    4140 non-null   float64
#  14  goal_11_score    4140 non-null   float64
#  15  goal_12_score    4140 non-null   float64
# ...

# %%
df.describe()
# Out:
#               year  sdg_index_score  goal_1_score  goal_2_score  goal_3_score  \
# count  4140.000000      4140.000000   4140.000000   4140.000000   4140.000000
# mean   2011.000000        63.685435     64.815628     57.735531     64.045652
# std       6.634051        10.776469     36.098836     11.121524     22.354993
# min    2000.000000        36.000000      0.000000      7.700000      5.900000
# 25%    2005.000000        55.075000     31.500000     52.400000     44.800000
# 50%    2011.000000        65.100000     81.000000     58.900000     70.200000
# 75%    2017.000000        72.000000     98.600000     65.300000     81.300000
# max    2022.000000        86.800000    100.000000     83.400000     97.300000
#
#        goal_4_score  goal_5_score  goal_6_score  goal_7_score  goal_8_score  \
# count   4140.000000   4140.000000   4140.000000   4140.000000   4140.000000
# mean      71.990048     55.803309     63.963188     57.340966     69.839493
# ...

# %% [markdown]
# ## 4. Data Cleaning

# %% [markdown]
# ### 4.1 Renaming Columns

# %%
# Renaming columns to be able to distinguish among goals with keywords

df.rename(columns = {'sdg_index_score' : 'sdg_index'}, inplace = True)
df.rename(columns = {'goal_1_score' : 'no_poverty'}, inplace = True)
df.rename(columns = {'goal_2_score' : 'zero_hunger'}, inplace = True)
df.rename(columns = {'goal_3_score' : 'good_health'}, inplace = True)
df.rename(columns = {'goal_4_score' : 'quality_education'}, inplace = True)
df.rename(columns = {'goal_5_score' : 'gender_equality'}, inplace = True)
df.rename(columns = {'goal_6_score' : 'clean_water'}, inplace = True)
df.rename(columns = {'goal_7_score' : 'affordable_energy'}, inplace = True)
df.rename(columns = {'goal_8_score' : 'economic_growth'}, inplace = True)
df.rename(columns = {'goal_9_score' : 'infrastructure_innovation'}, inplace = True)
df.rename(columns = {'goal_10_score' : 'reduced_inequalities'}, inplace = True)
df.rename(columns = {'goal_11_score' : 'sustainable_cities'}, inplace = True)
df.rename(columns = {'goal_12_score' : 'responsible_consumption'}, inplace = True)
df.rename(columns = {'goal_13_score' : 'climate_action'}, inplace = True)
df.rename(columns = {'goal_14_score' : 'underwater_life'}, inplace = True)
df.rename(columns = {'goal_15_score' : 'land_life'}, inplace = True)
df.rename(columns = {'goal_16_score' : 'peace_justice'}, inplace = True)
df.rename(columns = {'goal_17_score' : 'partnerships'}, inplace = True)

# %% [markdown]
# ### 4.2 Dropping / Adding Columns

# %%
# Dropping 'country_code' column

df = df.drop('country_code', axis=1)

# %% [markdown]
# ### 4.3 Changing Data Types

# %%
# Checking mixed data types in df

for col in df.columns.tolist():
      weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df[weird]) > 0:
        print (col)

# %% [markdown]
# #### No mixed-data types

# %%
df.dtypes
# Out:
# country                       object
# year                           int64
# sdg_index                    float64
# no_poverty                   float64
# zero_hunger                  float64
# good_health                  float64
# quality_education            float64
# gender_equality              float64
# clean_water                  float64
# affordable_energy            float64
# economic_growth              float64
# infrastructure_innovation    float64
# reduced_inequalities         float64
# sustainable_cities           float64
# responsible_consumption      float64
# climate_action               float64
# underwater_life              float64
# land_life                    float64
# peace_justice                float64
# partnerships                 float64
# dtype: object

# %% [markdown]
# #### Data types are correct

# %% [markdown]
# ### 4.4 Finding And Addressing Duplicates

# %%
# Finding duplicates in the df

df_dups = df[df.duplicated()]

# %% [markdown]
# #### No duplicates

# %% [markdown]
# ### 4.5 Handling Missing Values

# %%
# Checking for missing values in df

df.isna().sum()
# Out:
# country                      0
# year                         0
# sdg_index                    0
# no_poverty                   0
# zero_hunger                  0
# good_health                  0
# quality_education            0
# gender_equality              0
# clean_water                  0
# affordable_energy            0
# economic_growth              0
# infrastructure_innovation    0
# reduced_inequalities         0
# sustainable_cities           0
# responsible_consumption      0
# climate_action               0
# underwater_life              0
# land_life                    0
# peace_justice                0
# partnerships                 0
# dtype: int64

# %% [markdown]
# #### No missing values

# %% [markdown]
# ## 5. Exporting Data

# %%
# Exporting data

df.to_csv(os.path.join(path, '02 Data','Prepared Data', 'sdg_clean.csv'))
